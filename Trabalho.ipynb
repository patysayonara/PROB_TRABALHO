# %%
#Bibliotecas
import pandas as pd

# %%
#Dados
bolsistas_url = 'http://dados.ufrn.br/dataset/81608a4d-c76b-4758-a8d8-54be32209833/resource/d21c94fe-22ba-4cf3-89db-54d8e739c567/download/bolsistas-de-iniciacao-cientifica.csv'
bolsistas = pd.read_csv(bolsitas_url, sep=';')
bolsistas
# Out:
#        id_discente    matricula                              discente  \
# 0            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 1            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 2            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 3            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 4           545009   2011049415               ABEL LUIS DA SILVA NETO
# 5            74553    200234893               ABESON CORINGA DE MOURA
# 6           556964   2012903661                 ABIGAIL RUTE DA SILVA
# 7           531864   2010050304              ABIMAELLE SILVA CHIBÉRIO
# 8           531864   2010050304              ABIMAELLE SILVA CHIBÉRIO
# 9           523514   2009027132              ABIQUEILA ANGELO RIBEIRO
# 10          534594   2010075595            ABNER CARLOS COSTA DE MELO
# 11          534594   2010075595            ABNER CARLOS COSTA DE MELO
# ...

# %%
bolsistas.dtypes
# Out:
# id_discente              int64
# matricula                int64
# discente                object
# titulo                  object
# codigo_projeto          object
# id_projeto_pesquisa      int64
# ano                      int64
# id_orientador            int64
# orientador              object
# categoria               object
# tipo_de_bolsa           object
# linha_pesquisa          object
# id_grupo_pesquisa      float64
# grupo_pesquisa          object
# cota                    object
# inicio                  object
# fim                     object
# id_unidade               int64
# unidade                 object
# status                  object
# Unnamed: 20            float64
# dtype: object

# %%
#Por enquanto apenas de 2017.2
turma_url = 'http://dados.ufrn.br/dataset/1938623d-fb07-41a4-a55a-1691f7c3b8b5/resource/01fe7343-fdf0-4a67-b915-2386b7c2fecb/download/turmas-2017.2.csv'
turma = pd.read_csv(turma_url, sep=';')
turma
# Out:
#        id_turma codigo_turma  id_docente_interno  id_docente_externo  \
# 0      57602445           01                 NaN         120983811.0
# 1      57602445           01           5755233.0                 NaN
# 2      57602446           01           5757053.0                 NaN
# 3      57602447           01           5752677.0                 NaN
# 4      57602447           01           5755233.0                 NaN
# 5      57602448           01           5753094.0                 NaN
# 6      57602450           01                 NaN         124613183.0
# 7      57602450           01           5755233.0                 NaN
# 8      57602451           01                 NaN         125052419.0
# 9      57602451           01           5755233.0                 NaN
# 10     57602957           01           5753061.0                 NaN
# 11     57602961           01                 NaN         120050657.0
# 12     57602962           01           5752714.0                 NaN
# ...

# %%
turma.dtypes
# Out:
# id_turma                      int64
# codigo_turma                 object
# id_docente_interno          float64
# id_docente_externo          float64
# observacao                   object
# id_componente_curricular      int64
# nivel_ensino                 object
# campus_turma                 object
# local                        object
# ano                           int64
# periodo                       int64
# data_inicio                  object
# data_fim                     object
# descricao_horario            object
# total_solicitacoes          float64
# capacidade_aluno            float64
# tipo                         object
# distancia                    object
# data_consolidacao            object
# agrupadora                   object
# id_turma_agrupadora         float64
# qtd_aulas_lancadas          float64
# situacao_turma               object
# convenio                    float64
# modalidade_participantes     object
# Unnamed: 25                 float64
# ...

# %%
#Discentes ingressantes em 2017
#Talvez verificar quais dos alunos que estão em mestrado e doutorado em 2017(ou mais anos) fazem parte dos bolsistas
#Talvez fazer um merge pelos nomes
#Pegar os alunos de cada ano do IMD (dentre uma janela de tempo) e checar quantos são bolsistas (tentar contar apenas uma vez
# alunos que fizeram mais um tipo de iniciação científica)
#Talvez colocar esses dados em um gráfico para verificar o crescimento ou decrescimento 
discentes_url = 'http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/dc732572-a51a-4d4a-a39d-2db37cbe5382/download/discentes-2017'
discentes = pd.read_csv(discentes_url, sep=';')
discentes
# Out:
#         matricula                               nome_discente  ano_ingresso  \
# 0      2009021967               Abdias Beserra Pereira Júnior          2009
# 1      2009115809                            ABDO FARRET NETO          2009
# 2      2009048490  ABELARDO LOPES DE ALBUQUERQUE MACHADO NETO          2009
# 3      2009020804      ABELARDO MONTEIRO BEZERRA DE MELO NETO          2009
# 4      2009119915               ABIGAIL CALDAS BATISTA GONDIM          2009
# 5      2009110811            ABIGAIL NOÁDIA BARBALHO DA SILVA          2009
# 6      2009000048               ABÍLIO MONTEIRO DE FARIA NETO          2009
# 7      2009030800                      ABIMAEL SILVA CHIBÉRIO          2009
# 8      2009115845                   ABINADABE JACKSON DE MELO          2009
# 9      2009027132                    ABIQUEILA ANGELO RIBEIRO          2009
# 10     2009065681                ABNER FLAVIO TEIXEIRA SOARES          2009
# ...

# %%
discentes.dtypes
# Out:
# matricula                 int64
# nome_discente            object
# ano_ingresso              int64
# periodo_ingresso        float64
# forma_ingresso           object
# tipo_discente            object
# status                   object
# sigla_nivel_ensino       object
# nivel_ensino             object
# id_curso                float64
# nome_curso               object
# modalidade_educacao      object
# id_unidade              float64
# nome_unidade             object
# id_unidade_gestora      float64
# nome_unidade_gestora     object
# dtype: object
