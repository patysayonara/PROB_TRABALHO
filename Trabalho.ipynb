# %%
#Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Dados
bolsistas_url = 'http://dados.ufrn.br/dataset/81608a4d-c76b-4758-a8d8-54be32209833/resource/d21c94fe-22ba-4cf3-89db-54d8e739c567/download/bolsistas-de-iniciacao-cientifica.csv'
bolsistas = pd.read_csv(bolsistas_url, sep=';')
bolsistas
# Out:
#        id_discente    matricula                              discente  \
# 0            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 1            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 2            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 3            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 4           545009   2011049415               ABEL LUIS DA SILVA NETO
# 5            74553    200234893               ABESON CORINGA DE MOURA
# 6           556964   2012903661                 ABIGAIL RUTE DA SILVA
# 7           531864   2010050304              ABIMAELLE SILVA CHIBÉRIO
# 8           531864   2010050304              ABIMAELLE SILVA CHIBÉRIO
# 9           523514   2009027132              ABIQUEILA ANGELO RIBEIRO
# 10          534594   2010075595            ABNER CARLOS COSTA DE MELO
# 11          534594   2010075595            ABNER CARLOS COSTA DE MELO
# ...

# %%
bolsistas.rename(columns={'status':'status_projeto'}, inplace=True)
bolsistas.rename(columns={'ano': 'ano_projeto'}, inplace=True)

# %%
bolsistas
# Out:
#        id_discente    matricula                              discente  \
# 0            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 1            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 2            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 3            88234    200504593          ABDON SILVA RIBEIRO DA CUNHA
# 4           545009   2011049415               ABEL LUIS DA SILVA NETO
# 5            74553    200234893               ABESON CORINGA DE MOURA
# 6           556964   2012903661                 ABIGAIL RUTE DA SILVA
# 7           531864   2010050304              ABIMAELLE SILVA CHIBÉRIO
# 8           531864   2010050304              ABIMAELLE SILVA CHIBÉRIO
# 9           523514   2009027132              ABIQUEILA ANGELO RIBEIRO
# 10          534594   2010075595            ABNER CARLOS COSTA DE MELO
# 11          534594   2010075595            ABNER CARLOS COSTA DE MELO
# ...

# %%
bolsistas[(bolsistas.unidade.str.contains("INSTITUTO METROPOLE DIGITAL") == True) & (~bolsistas.matricula.duplicated())].count()
# Out:
# id_discente            76
# matricula              76
# discente               76
# titulo                 76
# codigo_projeto         76
# id_projeto_pesquisa    76
# ano_projeto            76
# id_orientador          76
# orientador             76
# categoria              76
# tipo_de_bolsa          76
# linha_pesquisa         76
# id_grupo_pesquisa      24
# grupo_pesquisa         24
# cota                   76
# inicio                 76
# fim                    40
# id_unidade             76
# unidade                76
# status_projeto         76
# Unnamed: 20             0
# dtype: int64

# %%
bolsistas[(bolsistas.unidade.str.contains("INSTITUTO METROPOLE DIGITAL") == True) & (bolsistas.ano_projeto == 2017)]
# Out:
#        id_discente    matricula                               discente  \
# 1030        693925   2015041845              ALLAN VALDIVINO GONÇALVES
# 4983        693541   2015034742   CINTHIA KATIANE ARAUJO DO NASCIMENTO
# 5884        714261   2016041661             DANIEL MARX PINTO CARVALHO
# 5888        714020   2016036840  DANIEL MIQUEIAS DO NASCIMENTO BARBOSA
# 14339       740040  20170102172          KADSON BRENO BENVINDO DE LIMA
# 16528       733943  20170008967          LUCAS RAMON BANDEIRA DA SILVA
# 16787       714384   2016044126           LUÍS EDUARDO ANUNCIADO SILVA
# 17989       698727  20150104474          MARIA ESTER DE CARVALHO VEIGA
# 18930       693643   2015036522         MATEUS SANTIAGO FERREIRA COSTA
# 25264       728548  20160154380       THÚLIO MATTHEUS PEREIRA DE SOUSA
#
#                                                   titulo codigo_projeto  \
# 1030          Detecção de Code Smells em sistemas Python  PIT14429-2017
# ...

# %%
bolsistas.unidade[bolsistas.unidade == 'INSTITUTO METROPOLE DIGITAL - IMD'].count()
# Out:
# 119

# %%
bolsistas.dtypes
# Out:
# id_discente              int64
# matricula                int64
# discente                object
# titulo                  object
# codigo_projeto          object
# id_projeto_pesquisa      int64
# ano_projeto              int64
# id_orientador            int64
# orientador              object
# categoria               object
# tipo_de_bolsa           object
# linha_pesquisa          object
# id_grupo_pesquisa      float64
# grupo_pesquisa          object
# cota                    object
# inicio                  object
# fim                     object
# id_unidade               int64
# unidade                 object
# status_projeto          object
# Unnamed: 20            float64
# dtype: object

# %%
bolsistas.isnull().sum()
# Out:
# id_discente                0
# matricula                  0
# discente                   0
# titulo                     9
# codigo_projeto             0
# id_projeto_pesquisa        0
# ano_projeto                0
# id_orientador              0
# orientador                 0
# categoria                  0
# tipo_de_bolsa              0
# linha_pesquisa           862
# id_grupo_pesquisa       4247
# grupo_pesquisa          4289
# cota                       0
# inicio                     5
# fim                     3306
# id_unidade                 0
# unidade                    0
# status_projeto             0
# Unnamed: 20            26712
# dtype: int64

# %%
#Discentes ingressantes 
#Pegar de 2013 a 2016
#Talvez verificar quais dos alunos que estão em mestrado e doutorado em 2017(ou mais anos) fazem parte dos bolsistas
#Talvez fazer um merge pelo numero da matricula
#Pegar os alunos de cada ano do IMD (dentre uma janela de tempo) e checar quantos são bolsistas (tentar contar apenas uma vez
# alunos que fizeram mais um tipo de iniciação científica)
#Talvez colocar esses dados em um gráfico para verificar o crescimento ou decrescimento 
discentes2013_url = 'http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/dba208c2-822f-4e26-adc3-b61d4cb110b6/download/discentes-2013' 
discentes2013 = pd.read_csv(discentes2013_url, sep=';')
discentes2013
# Out:
#           matricula                                 nome_discente  \
# 0      2.013010e+09           ABA-ELBER GEORGE PEREIRA CAVALCANTE
# 1      2.013309e+09                    ABDENOR BEZERRA DOS SANTOS
# 2      2.013092e+09                    ABDENOR BEZERRA DOS SANTOS
# 3      2.013336e+09                      ABDOM DOS SANTOS CANINDÉ
# 4      2.013321e+09             ABELARDO BRUNDLE RODRIGUEZ DANTAS
# 5      2.013304e+09                  ABEL LAMEQUE SILVA DAMASCENO
# 6      2.013121e+09                         ABEL SILVINO DO MONTE
# 7      2.013017e+09                       ABESON CORINGA DE MOURA
# 8      2.013360e+09                  ABIAS DIAS TAVARES DE ARAUJO
# 9      2.013341e+09                         ABIGAIL ALVES DE LIMA
# 10     2.013504e+09         ABIGAIL JESSICA DA SILVA ARAUJO GOMES
# 11     2.013513e+09         ABIGAIL JESSICA DA SILVA ARAUJO GOMES
# 12     2.013008e+09                  ABIMAEL AMARO XAVIER BARBOSA
# ...

# %%
discentes2013.isnull().sum()
# Out:
# matricula                  2
# nome_discente              0
# ano_ingresso               0
# periodo_ingresso          13
# forma_ingresso            59
# tipo_discente              0
# status                     0
# sigla_nivel_ensino         0
# nivel_ensino               0
# id_curso                1263
# nome_curso              1263
# modalidade_educacao     1263
# id_unidade              1263
# nome_unidade            1263
# id_unidade_gestora      1263
# nome_unidade_gestora    1263
# dtype: int64

# %%
discentes2013.drop(labels=[3090, 20654], inplace=True)

# %%
discentes2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21791 entries, 0 to 21792
# Data columns (total 16 columns):
# matricula               21791 non-null float64
# nome_discente           21791 non-null object
# ano_ingresso            21791 non-null int64
# periodo_ingresso        21778 non-null float64
# forma_ingresso          21732 non-null object
# tipo_discente           21791 non-null object
# status                  21791 non-null object
# sigla_nivel_ensino      21791 non-null object
# nivel_ensino            21791 non-null object
# id_curso                20528 non-null float64
# nome_curso              20528 non-null object
# modalidade_educacao     20528 non-null object
# id_unidade              20528 non-null float64
# nome_unidade            20528 non-null object
# id_unidade_gestora      20528 non-null float64
# nome_unidade_gestora    20528 non-null object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 2.8+ MB

# %%
discentes2013.matricula = discentes2013.matricula.astype(np.int64)
discentes2013
# Out:
#         matricula                                 nome_discente  ano_ingresso  \
# 0      2013010008           ABA-ELBER GEORGE PEREIRA CAVALCANTE          2013
# 1      2013309148                    ABDENOR BEZERRA DOS SANTOS          2013
# 2      2013092308                    ABDENOR BEZERRA DOS SANTOS          2013
# 3      2013335827                      ABDOM DOS SANTOS CANINDÉ          2013
# 4      2013320691             ABELARDO BRUNDLE RODRIGUEZ DANTAS          2013
# 5      2013303574                  ABEL LAMEQUE SILVA DAMASCENO          2013
# 6      2013121007                         ABEL SILVINO DO MONTE          2013
# 7      2013016861                       ABESON CORINGA DE MOURA          2013
# 8      2013360211                  ABIAS DIAS TAVARES DE ARAUJO          2013
# 9      2013341261                         ABIGAIL ALVES DE LIMA          2013
# 10     2013503600         ABIGAIL JESSICA DA SILVA ARAUJO GOMES          2013
# ...

# %%
discentes2013.dtypes
# Out:
# matricula                 int64
# nome_discente            object
# ano_ingresso              int64
# periodo_ingresso        float64
# forma_ingresso           object
# tipo_discente            object
# status                   object
# sigla_nivel_ensino       object
# nivel_ensino             object
# id_curso                float64
# nome_curso               object
# modalidade_educacao      object
# id_unidade              float64
# nome_unidade             object
# id_unidade_gestora      float64
# nome_unidade_gestora     object
# dtype: object

# %%
discentes2014_url = 'http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/6c23a430-9a7c-4d0f-9602-1d5d97d40e6a/download/discentes-2014'
discentes2014 = pd.read_csv(discentes2014_url, sep=';')
discentes2014
# Out:
#          matricula                           nome_discente  ano_ingresso  \
# 0       2014000000                                       A          2014
# 1       2014338411       AARON LEONEL DE ALMEIDA DAMASCENO          2014
# 2       2014351932         ABDENIO VICTOR PEREIRA DA SILVA          2014
# 3       2014048289           ABDIAS MARTINS DE CASTRO NETO          2014
# 4       2014322574             ABDI SADDAI COSTA DE ARAÚJO          2014
# 5       2014066385                ABDOM DOS SANTOS CANINDÉ          2014
# 6       2014100905            ABDON SILVA RIBEIRO DA CUNHA          2014
# 7       2014128880  ABELARDO MONTEIRO BEZERRA DE MELO NETO          2014
# 8       2014036760                     ABEL MENDONCA ALVES          2014
# 9       2014313127                   ABEL VENANCIO DO VALE          2014
# 10      2014045714                 ABESON CORINGA DE MOURA          2014
# 11      2014216375              ABIA FERNANDES DE OLIVEIRA          2014
# ...

# %%
discentes2014.dtypes
# Out:
# matricula                 int64
# nome_discente            object
# ano_ingresso              int64
# periodo_ingresso          int64
# forma_ingresso           object
# tipo_discente            object
# status                   object
# sigla_nivel_ensino       object
# nivel_ensino             object
# id_curso                float64
# nome_curso               object
# modalidade_educacao      object
# id_unidade              float64
# nome_unidade             object
# id_unidade_gestora      float64
# nome_unidade_gestora     object
# dtype: object

# %%
discentes2014.isnull().sum()
# Out:
# matricula                  0
# nome_discente              0
# ano_ingresso               0
# periodo_ingresso           0
# forma_ingresso            76
# tipo_discente              0
# status                     0
# sigla_nivel_ensino         0
# nivel_ensino               0
# id_curso                1296
# nome_curso              1296
# modalidade_educacao     1296
# id_unidade              1296
# nome_unidade            1296
# id_unidade_gestora      1296
# nome_unidade_gestora    1296
# dtype: int64

# %%
discentes2014.periodo_ingresso = discentes2014.periodo_ingresso.astype(np.float64)
discentes2014
# Out:
#          matricula                           nome_discente  ano_ingresso  \
# 0       2014000000                                       A          2014
# 1       2014338411       AARON LEONEL DE ALMEIDA DAMASCENO          2014
# 2       2014351932         ABDENIO VICTOR PEREIRA DA SILVA          2014
# 3       2014048289           ABDIAS MARTINS DE CASTRO NETO          2014
# 4       2014322574             ABDI SADDAI COSTA DE ARAÚJO          2014
# 5       2014066385                ABDOM DOS SANTOS CANINDÉ          2014
# 6       2014100905            ABDON SILVA RIBEIRO DA CUNHA          2014
# 7       2014128880  ABELARDO MONTEIRO BEZERRA DE MELO NETO          2014
# 8       2014036760                     ABEL MENDONCA ALVES          2014
# 9       2014313127                   ABEL VENANCIO DO VALE          2014
# 10      2014045714                 ABESON CORINGA DE MOURA          2014
# 11      2014216375              ABIA FERNANDES DE OLIVEIRA          2014
# ...

# %%
discentes2015_url = 'http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/e2b5b843-4f58-497e-8979-44daf8df8f94/download/discentes-2015'
discentes2015 = pd.read_csv(discentes2015_url, sep=';')
discentes2015
# Out:
#          matricula                          nome_discente  ano_ingresso  \
# 0       2015092254                ABIGAIL DANTAS TEIXEIRA          2015
# 1       2015306913            ABÍLIO GABRIEL MAIA DE LIMA          2015
# 2       2015108990  ABIMAEL ESDRAS CARVALHO DE MOURA LIRA          2015
# 3       2015304178      ABIMAEL FELIPE DE ARAUJO OLIVEIRA          2015
# 4       2015105700               ABIMAELLE SILVA CHIBÉRIO          2015
# 5       2015023014           ABNER DE JESUS BRITO BARRETO          2015
# 6       2015307106                 ABNER DE SANTANA SILVA          2015
# 7       2015030716                     ABNER PINTO SOARES          2015
# 8      20155008452                     ABNER PINTO SOARES          2015
# 9      20150110050            ABRAAO JORDAO GREGORIO MOTA          2015
# 10      2015308337         ABRAÃO JOSÉ AZEVEDO DOS SANTOS          2015
# 11      2015100768          ABRAÃO LINCOLN ROSENDO FRAZÃO          2015
# ...

# %%
discentes2015.dtypes
# Out:
# matricula                 int64
# nome_discente            object
# ano_ingresso              int64
# periodo_ingresso        float64
# forma_ingresso           object
# tipo_discente            object
# status                   object
# sigla_nivel_ensino       object
# nivel_ensino             object
# id_curso                float64
# nome_curso               object
# modalidade_educacao      object
# id_unidade              float64
# nome_unidade             object
# id_unidade_gestora      float64
# nome_unidade_gestora     object
# dtype: object

# %%
discentes2015.isnull().sum()
# Out:
# matricula                  0
# nome_discente              0
# ano_ingresso               0
# periodo_ingresso          13
# forma_ingresso            87
# tipo_discente              0
# status                     0
# sigla_nivel_ensino         0
# nivel_ensino               0
# id_curso                1348
# nome_curso              1348
# modalidade_educacao     1348
# id_unidade              1348
# nome_unidade            1348
# id_unidade_gestora      1348
# nome_unidade_gestora    1348
# dtype: int64

# %%
discentes2016_url = 'http://dados.ufrn.br/dataset/554c2d41-cfce-4278-93c6-eb9aa49c5d16/resource/7d2fa5b3-743f-465f-8450-91719b34a002/download/discentes-2016'
discentes2016 = pd.read_csv(discentes2016_url, sep=';')
discentes2016
# Out:
#          matricula                          nome_discente  ano_ingresso  \
# 0      20163010606            AADRIAN ANDREW COSTA BORGES          2016
# 1      20163029715            ABDENEGO BATISTA DOS SANTOS          2016
# 2       2016092160        ABDENIO VICTOR PEREIRA DA SILVA          2016
# 3       2016015830                   ABELARDO MACEDO NETO          2016
# 4       2016022817           ABEL GOMES DE OLIVEIRA FILHO          2016
# 5      20160133934             ABEL VICENTE DE LIMA FILHO          2016
# 6      20163003218      ABIB RAUEL COSTA BEZERRA REBOUÇAS          2016
# 7       2016060148            ÁBIDA HELLEN BARROS PEREIRA          2016
# 8      20160138841              ABIGAIL MARIZA DE ANDRADE          2016
# 9      20163008958       ABÍLIO FONTENELLE MAGALHÃES NETO          2016
# 10     20163001320          ABÍLIO MONTEIRO DE FARIA NETO          2016
# 11     20161020256           ABIMAEL AMARO XAVIER BARBOSA          2016
# ...

# %%
discentes2016.dtypes
# Out:
# matricula                 int64
# nome_discente            object
# ano_ingresso              int64
# periodo_ingresso        float64
# forma_ingresso           object
# tipo_discente            object
# status                   object
# sigla_nivel_ensino       object
# nivel_ensino             object
# id_curso                float64
# nome_curso               object
# modalidade_educacao      object
# id_unidade              float64
# nome_unidade             object
# id_unidade_gestora      float64
# nome_unidade_gestora     object
# dtype: object

# %%
discentes2016.isnull().sum()
# Out:
# matricula                  0
# nome_discente              0
# ano_ingresso               0
# periodo_ingresso          28
# forma_ingresso             3
# tipo_discente              0
# status                     0
# sigla_nivel_ensino         0
# nivel_ensino               0
# id_curso                1705
# nome_curso              1705
# modalidade_educacao     1705
# id_unidade              1705
# nome_unidade            1705
# id_unidade_gestora      1705
# nome_unidade_gestora    1705
# dtype: int64

# %%
#Pegando quantos discentes de 2013 se engajaram em projetos de iniciação cientifica ou tecnologica
colunas = ["matricula", "nome_discente", "ano_ingresso", "codigo_projeto", "orientador", "ano_projeto", "categoria", "unidade", "nivel_ensino", "status", "nome_curso", "nome_unidade", "nome_unidade_gestora"]
merge_bolsistas_discentes2013 = pd.merge(bolsistas, discentes2013, on='matricula')[colunas]
bolsistas_discentes2013 = merge_bolsistas_discentes2013[~merge_bolsistas_discentes2013.matricula.duplicated()]
bolsistas_discentes2013
# Out:
#        matricula                                 nome_discente  ano_ingresso  \
# 0     2013037496                      ACSA MARESA LUCAS URBANO          2013
# 1     2013062640            ADALGISA PAULA DE OLIVEIRA MARTINS          2013
# 2     2013021440                    ADEILSON DE OLIVEIRA SOUZA          2013
# 4     2013063988                 ADELSON DIAS DE ARAÚJO JÚNIOR          2013
# 5     2013026886                     ADIELSON PEREIRA DA SILVA          2013
# 7     2013012343               ADILSON TAVARES DE BRITO JÚNIOR          2013
# 8     2013027542              ADRIANA KARLA NASCIMENTO BEZERRA          2013
# 9     2013027195               ADRIANA MARINA FERREIRA DO RÊGO          2013
# 10    2013067851                       ADRIANE GUERREIRO LEMOS          2013
# 11    2013039900      ADRIELLY MARCELA DE CASTRO DO NASCIMENTO          2013
# 17    2013035123                 ADRYELLE FERREIRA DE OLIVEIRA          2013
# ...

# %%
bolsistas_discentes2013[(bolsistas_discentes2013.matricula.duplicated() == True) & (bolsistas_discentes2013.codigo_projeto.duplicated() == True)]
# Out:
# Empty DataFrame
# Columns: [matricula, nome_discente, ano_ingresso, codigo_projeto, orientador, ano_projeto, categoria, unidade, nivel_ensino, status, nome_curso, nome_unidade, nome_unidade_gestora]
# Index: []

# %%
colunas = ["matricula", "nome_discente", "ano_ingresso", "codigo_projeto", "orientador", "ano_projeto", "categoria", "unidade", "nivel_ensino", "status", "nome_curso", "nome_unidade", "nome_unidade_gestora"]
merge_bolsistas_discentes2014 = pd.merge(bolsistas, discentes2014, on='matricula')[colunas]
bolsistas_discentes2014 = merge_bolsistas_discentes2014[~merge_bolsistas_discentes2014.matricula.duplicated()]
bolsistas_discentes2014
# Out:
#        matricula                             nome_discente  ano_ingresso  \
# 0     2014058300                    ADARA PEREIRA DA SILVA          2014
# 2     2014338654                  ADDYSON SALES DE ALMEIDA          2014
# 4     2014052497           ADOLFO DE ALENCAR EULALIO FILHO          2014
# 6     2014051909                     ADONIAS FERREIRA NETO          2014
# 7     2014019868      ADRIANA PERPETUA FIGUEIREDO PAULISTA          2014
# 9     2014058249                  ADRIANO CAMPELO DA SILVA          2014
# 10    2014087410                     ADRIEL SOARES MARTINS          2014
# 12    2014064934              AFONSON LUIZ MEDEIROS GONDIM          2014
# 13    2014086280               AGUIDA MARIA DA SILVA CUNHA          2014
# 17    2014082496                  AIMEE ATAIDE DE OLIVEIRA          2014
# 18    2014048108                   ALANA SANTOS DE FREITAS          2014
# 20    2014070735          ALANA TAMIRES FERNANDES DE SOUZA          2014
# ...

# %%
colunas = ["matricula", "nome_discente", "ano_ingresso", "codigo_projeto", "orientador", "ano_projeto", "categoria", "unidade", "nivel_ensino", "status", "nome_curso", "nome_unidade", "nome_unidade_gestora"]
merge_bolsistas_discentes2015 = pd.merge(bolsistas, discentes2015, on='matricula')[colunas]
bolsistas_discentes2015 = merge_bolsistas_discentes2015[~merge_bolsistas_discentes2015.matricula.duplicated()]
bolsistas_discentes2015
# Out:
#         matricula                              nome_discente  ano_ingresso  \
# 0      2015070981                 ABRAAO SILVEIRA DE ANDRADE          2015
# 1      2015009150              ACÁCIO LOPES BORGES DE ARAÚJO          2015
# 3      2015031230           ADELINO AFONSO FERNANDES AVELINO          2015
# 4      2015074800               ÁDILA VIRGÍNIA SILVA E SOUZA          2015
# 5      2015077768                 ADOLFO DE MATOS COSTA NETO          2015
# 7      2015062068     ADRIANA CRISTINA XAVIER DEIGA FERREIRA          2015
# 8     20150122697    ADRIANE DO LIVRAMENTO COELHO DOS SANTOS          2015
# 9      2015074247            ADRIAN LUCCA GUIMARAES CALDEIRA          2015
# 10     2015080128              AGENOR FRANCISCO RIBEIRO NETO          2015
# 11     2015064400           AGUIBERTO CANDIDO DA SILVA FILHO          2015
# 13     2015033520             AILTON BARBOSA DA SILVA JÚNIOR          2015
# ...

# %%
colunas = ["matricula", "nome_discente", "ano_ingresso", "codigo_projeto", "orientador", "ano_projeto", "categoria", "unidade", "nivel_ensino", "status", "nome_curso", "nome_unidade", "nome_unidade_gestora"]
merge_bolsistas_discentes2016 = pd.merge(bolsistas, discentes2016, on='matricula')[colunas]
bolsistas_discentes2016 = merge_bolsistas_discentes2016[~merge_bolsistas_discentes2016.matricula.duplicated()]
bolsistas_discentes2016
# Out:
#        matricula                           nome_discente  ano_ingresso  \
# 0     2016093363                 ACTON ALVES DE OLIVEIRA          2016
# 1     2016007230              ADEILSON DE OLIVEIRA SOUZA          2016
# 2     2016007365             ADRIANA RIBEIRO DE OLIVEIRA          2016
# 4     2016074180                     AELTON SILVA ARAUJO          2016
# 6    20160132310         ÁKILLA VICENTE BRAGA NASCIMENTO          2016
# 7     2016077000              ALESANDRA PEREIRA DA SILVA          2016
# 9    20160148365           ALESSANDRA DIAS DE LUNA SILVA          2016
# 10   20160134664     ALESSANNA LARISSA AZEVEDO VITORIANO          2016
# 11   20163026642               ALEXANDRE ARAUJO DE ASSIS          2016
# 12    2016012436               ALEXANDRE DE SOUSA CAMPOS          2016
# 13   20160152733     ALEXANDRE GUTIERRY MELO DE OLIVEIRA          2016
# 14    2016317330           ALEXANDY MICHEL DANTAS SANTOS          2016
# ...

# %%
imd_2013 = bolsistas_discentes2013[bolsistas_discentes2013.nome_unidade.str.contains("INSTITUTO METROPOLE DIGITAL")]
imd_2013
# Out:
#        matricula                                      nome_discente  \
# 101   2013043063                     ÁLVARO PORTELA FIGUEIREDO NETO
# 110   2013309863                                AMANDA ARAUJO SILVA
# 181   2013020416                           ANA PAULA LOPES DE SOUZA
# 191   2013019470                             ANDERSON MATHEUS SILVA
# 425   2013023300                   CEPHAS ALVES DA SILVEIRA BARRETO
# 441   2013018973                                 CIRO MARTINS PINTO
# 505   2013046851                        DANIEL TIAGO DE SOUZA BRITO
# 684   2013023490                                 FAGNER MORAIS DIAS
# 750   2013017608                        FRANCISCO LAÉRCIO DE MORAIS
# 762   2013022760                       GABRIELA CAVALCANTE DA SILVA
# 790   2013043804                          GABRIEL ROCHA DE OLIVEIRA
# 795   2013021870                                   GELLY VIANA MOTA
# 873   2013020550                             HANNAH PEREGRINO ALVES
# ...

# %%
bolsistas_discentes2014.drop(labels=737, inplace=True)
# Out:
# C:\Users\paty_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
imd_2014 = bolsistas_discentes2014[bolsistas_discentes2014.nome_unidade.str.contains("INSTITUTO METROPOLE DIGITAL")]
imd_2014
# Out:
#        matricula                         nome_discente  ano_ingresso  \
# 300   2014065190       BRENO MAURICIO DE FREITAS VIANA          2014
# 301   2014065216        BRENO WESLEY BATISTA DE ARAÚJO          2014
# 336   2014065440                 CANOI GOMES DE AGUIAR          2014
# 436   2014026450           DEBORA EMILI COSTA OLIVEIRA          2014
# 577   2014025963                 FELIPE BARBALHO ROCHA          2014
# 891   2014029701        JACKSON RAUUP SILVESTRE SANTOS          2014
# 899   2014026488     JAIMERSON LEANDRO AMARO DE ARAÚJO          2014
# 959   2014028052                    JOAO SANTANA BELAU          2014
# 995   2014042534           JOSÉ GAMELEIRA DO RÊGO NETO          2014
# 1087  2014056502   KATYANNA AMÉLIA MOURA DO NASCIMENTO          2014
# 1406  2014026737              MATHEUS CASSIANO DE GOES          2014
# 1457  2014027510                MURILO DE ARAUJO BENTO          2014
# 1535  2014048977        PAULO SERGIO SILVA DE MENDONÇA          2014
# ...

# %%
imd_2015 = bolsistas_discentes2015[bolsistas_discentes2015.nome_unidade.str.contains("INSTITUTO METROPOLE DIGITAL")]
imd_2015
# Out:
#         matricula                                 nome_discente  ano_ingresso  \
# 3      2015031230              ADELINO AFONSO FERNANDES AVELINO          2015
# 58     2015041845                     ALLAN VALDIVINO GONÇALVES          2015
# 74     2015032710             AMANDA MARIA DOMINGOS DE OLIVEIRA          2015
# 135    2015035946                  ANDRE LUIZ DE LUCENA MOREIRA          2015
# 298    2015304650     CHRISTOPHER MATHEUS FLORENCIO RAMOS NEVES          2015
# 299    2015034742          CINTHIA KATIANE ARAUJO DO NASCIMENTO          2015
# 315    2015306299                        CLEYTON DA SILVA VITOR          2015
# 376    2015044284              DÉBORA KAROLINE SILVA DE AZEVEDO          2015
# 407    2015002669                          DILBERTO CHAVES LIMA          2015
# 559    2015315000  GIANKARLO ROCHA FREIRE FERNANDES DE OLIVEIRA          2015
# 570    2015031750              GIOVANNI FRANCO DE PAULA ROSARIO          2015
# ...

# %%
imd_2016 = bolsistas_discentes2016[bolsistas_discentes2016.nome_unidade.str.contains("INSTITUTO METROPOLE DIGITAL")]
imd_2016
# Out:
#        matricula                              nome_discente  ano_ingresso  \
# 60    2016044304            ANDERSON CAIO DA FONSECA SANTOS          2016
# 79   20163002847            ÁQUILA FILÊMON DE ANDRADE COSTA          2016
# 106   2016042300                  Bianca Rodrigues Cesarino          2016
# 157   2016041661                 DANIEL MARX PINTO CARVALHO          2016
# 158   2016036840      DANIEL MIQUEIAS DO NASCIMENTO BARBOSA          2016
# 165   2016009270                       DANILO LOPES MARTINS          2016
# 241   2016041545               FELIPE XAVIER DE ALBUQUERQUE          2016
# 257  20163013878             FRANTYHERE SILVA DO NASCIMENTO          2016
# 260   2016042088                    GABRIEL ARAUJO DE SOUZA          2016
# 365   2016091387      JEFFERSON RAYLAN NASCIMENTO DE MACÊDO          2016
# 375  20160114240            JHONATTAN CARLOS BARBOSA CABRAL          2016
# 525   2016044126               LUÍS EDUARDO ANUNCIADO SILVA          2016
# ...

# %%
#Talvez comparar o total de professores do imd e quantos ficaram engajados em iniciação científica ou tecnológica
#Comparar entre os professores que orientaram bolsistas no geral e os do imd
imd_anos = [imd_2013, imd_2014, imd_2015, imd_2016]
imd_total = pd.concat(imd_anos)
imd_total
# Out:
#         matricula                                      nome_discente  \
# 101    2013043063                     ÁLVARO PORTELA FIGUEIREDO NETO
# 110    2013309863                                AMANDA ARAUJO SILVA
# 181    2013020416                           ANA PAULA LOPES DE SOUZA
# 191    2013019470                             ANDERSON MATHEUS SILVA
# 425    2013023300                   CEPHAS ALVES DA SILVEIRA BARRETO
# 441    2013018973                                 CIRO MARTINS PINTO
# 505    2013046851                        DANIEL TIAGO DE SOUZA BRITO
# 684    2013023490                                 FAGNER MORAIS DIAS
# 750    2013017608                        FRANCISCO LAÉRCIO DE MORAIS
# 762    2013022760                       GABRIELA CAVALCANTE DA SILVA
# 790    2013043804                          GABRIEL ROCHA DE OLIVEIRA
# 795    2013021870                                   GELLY VIANA MOTA
# 873    2013020550                             HANNAH PEREGRINO ALVES
# ...

# %%
#Gráfico da distribuição de alunos ingressantes do IMD que tiveram bolsa para iniciação científica ou tecnológica, 2013-2016
sns.set()
sns.set_style('dark')
sns.set_context("notebook")
sns.distplot(imd_total['ano_ingresso'])
plt.xlabel("Ano de Ingresso")
plt.title("Distribuição de Discentes do IMD com Bolsas de Iniciação Científica ou Tecnológica")
plt.show()

# %%
imd_total.matricula.count()
# Out:
# 120

# %%
bolsistas[~bolsistas.matricula.duplicated()].matricula.count()
# Out:
# 14437

# %%
(imd_total.matricula.count()/bolsistas[~bolsistas.matricula.duplicated()].matricula.count())*100
# Out:
# 0.8311976172334973

# %%
imd_total.orientador.value_counts()
# Out:
# APUENA VIEIRA GOMES                       8
# EDUARDO HENRIQUE DA SILVA ARANHA          6
# IVANOVITCH MEDEIROS DANTAS DA SILVA       5
# ALUIZIO FERREIRA DA ROCHA NETO            5
# JORGE ESTEFANO SANTANA DE SOUZA           5
# EUGENIO PACCELLI AGUIAR FREIRE            5
# EDGARD DE FARIA CORREA                    4
# ALYSON MATHEUS DE CARVALHO SOUZA          4
# ELIZABETH FERREIRA GOUVEA GOLDBARG        4
# MONICA MAGALHAES PEREIRA                  4
# DENNYS LEITE MAIA                         4
# EIJI ADACHI MEDEIROS BARBOSA              3
# FREDERICO ARAUJO DA SILVA LOPES           3
# MARCIA JACYNTHA NUNES RODRIGUES LUCENA    3
# CARLOS EDUARDO DA SILVA                   3
# GIBEON SOARES DE AQUINO JUNIOR            3
# UIRA KULESZA                              3
# GUSTAVO GIRAO BARRETO DA SILVA            3
# ISABEL DILLMANN NUNES                     3
# DANIEL SABINO AMORIM DE ARAUJO            2
# THAIS VASCONCELOS BATISTA                 2
# ...

# %%
imd_total[~imd_total.codigo_projeto.duplicated()].orientador.value_counts()
# Out:
# MONICA MAGALHAES PEREIRA                  4
# EUGENIO PACCELLI AGUIAR FREIRE            3
# ALUIZIO FERREIRA DA ROCHA NETO            3
# EIJI ADACHI MEDEIROS BARBOSA              2
# GUSTAVO GIRAO BARRETO DA SILVA            2
# JORGE ESTEFANO SANTANA DE SOUZA           2
# ALYSON MATHEUS DE CARVALHO SOUZA          2
# EDUARDO HENRIQUE DA SILVA ARANHA          2
# CARLOS EDUARDO DA SILVA                   2
# DANIEL SABINO AMORIM DE ARAUJO            2
# MARCIA JACYNTHA NUNES RODRIGUES LUCENA    2
# IVANOVITCH MEDEIROS DANTAS DA SILVA       2
# AUGUSTO JOSE VENANCIO NETO                2
# EDGARD DE FARIA CORREA                    2
# MATTHIEU SEBASTIEN CASTRO                 1
# JOAO MARCOS DE ALMEIDA                    1
# ADRIANO BRETANHA LOPES TORT               1
# UIRA KULESZA                              1
# LEONARDO CESAR TEONACIO BEZERRA           1
# VALENTIN OBAC RODA                        1
# SANDRO JOSE DE SOUZA                      1
# ...

# %% [markdown]
# Gráficos:
#     Entre o total de bolsistas e os do imd entre 2013 e 2016 (histograma, grafico de barras, grafico de linhas...);
#     Variação da quantidade de bolsistas por ano;
#     Quais professores tiveram maior quantidade de bolsistas;
#     Quais professores orientaram em diferentes projetos;
